# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.cov()
# Out:
#                   sl_no         ssc_p         hsc_p     degree_p  \
# sl_no       3870.000000    -52.641355    -58.106028   -40.413645
# ssc_p        -52.641355    117.228377     60.348373    42.897137
# hsc_p        -58.106028     60.348373    118.755706    34.819820
# degree_p     -40.413645     42.897137     34.819820    54.151103
# etest_p       52.556168     37.659225     35.461678    21.929469
# mba_p          8.102336     24.535952     22.555846    17.272020
# salary    248400.921950  19767.643976  46008.057275 -8064.357161
#
#                 etest_p         mba_p        salary
# sl_no         52.556168      8.102336  2.484009e+05
# ssc_p         37.659225     24.535952  1.976764e+04
# hsc_p         35.461678     22.555846  4.600806e+04
# degree_p      21.929469     17.272020 -8.064357e+03
# etest_p      176.251018     16.886973  1.571579e+05
# mba_p         16.886973     34.028376  6.611551e+04
# salary    157157.850783  66115.509283  5.999726e+09

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Define the covariance matrix
data = {
    'sl_no': [3870.000000, -52.641355, -58.106028, -40.413645, 52.556168, 8.102336, 248400.921950],
    'ssc_p': [-52.641355, 117.228377, 60.348373, 42.897137, 37.659225, 24.535952, 19767.643976],
    'hsc_p': [-58.106028, 60.348373, 118.755706, 34.819820, 35.461678, 22.555846, 46008.057275],
    'degree_p': [-40.413645, 42.897137, 34.819820, 54.151103, 21.929469, 17.272020, -8064.357161],
    'etest_p': [52.556168, 37.659225, 35.461678, 21.929469, 176.251018, 16.886973, 157157.850783],
    'mba_p': [8.102336, 24.535952, 22.555846, 17.272020, 16.886973, 34.028376, 66115.509283],
    'salary': [248400.921950, 19767.643976, 46008.057275, -8064.357161, 157157.850783, 66115.509283, 5.999726e+09]
}

# Create the covariance DataFrame
cov_matrix = pd.DataFrame(data, index=['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'])

# Plot the covariance heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cov_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Covariance Matrix Heatmap')
plt.show()

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.051550
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.023571
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.054506
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.014148
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.152829
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.146324
# salary    0.051550  0.023571  0.054506 -0.014148  0.152829  0.146324  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample correlation matrix (replace with your data)
import pandas as pd
data = {
    'sl_no': [1, -0.078, -0.086, -0.088, 0.063, 0.022, 0.051],
    'ssc_p': [-0.078, 1, 0.511, 0.538, 0.262, 0.388, 0.024],
    'hsc_p': [-0.086, 0.511, 1, 0.434, 0.245, 0.355, 0.055],
    'degree_p': [-0.088, 0.538, 0.434, 1, 0.224, 0.402, -0.014],
    'etest_p': [0.063, 0.262, 0.245, 0.224, 1, 0.218, 0.153],
    'mba_p': [0.022, 0.388, 0.355, 0.402, 0.218, 1, 0.146],
    'salary': [0.051, 0.024, 0.055, -0.014, 0.153, 0.146, 1]
}
df = pd.DataFrame(data, index=['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'])

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.000000      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.000000      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.000000      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  288655.405405      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.000000      M  Central
# ..     ...    ...       ...      ...    ...            ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.000000      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.000000      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.000000      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.000000      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  288655.405405      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(x):
    vif=pd.DataFrame()
    vif["variance"]=x.columns
    vif["vif"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return vif

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variance        vif
# 0  etest_p  11.944567
# 1   salary  11.944567

# %%
dataset[dataset['gender']=='F']["salary"]
# Out:
# 6      288655.405405
# 12     288655.405405
# 13     218000.000000
# 15     200000.000000
# 17     288655.405405
#            ...
# 197    260000.000000
# 198    288655.405405
# 204    210000.000000
# 208    288655.405405
# 213    204000.000000
# Name: salary, Length: 76, dtype: float64

# %%
dataset[dataset['gender']=='M']["salary"]
# Out:
# 0      270000.000000
# 1      200000.000000
# 2      250000.000000
# 3      288655.405405
# 4      425000.000000
#            ...
# 209    216000.000000
# 210    400000.000000
# 211    275000.000000
# 212    295000.000000
# 214    288655.405405
# Name: salary, Length: 139, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']['salary']
female=dataset[dataset['gender']=='F']['salary']
ttest_ind(male,female)
# Out:
# Ttest_indResult(statistic=1.9001627265152634, pvalue=0.05876239427122642)

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']['ssc_p']
male1=dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male,male1)
# Out:
# Ttest_relResult(statistic=0.6852881050898078, pvalue=0.49431164600731503)

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
female=dataset[dataset['gender']=='F']['ssc_p']
female1=dataset[dataset['gender']=='F']['hsc_p']
ttest_rel(female,female1)
# Out:
# Ttest_relResult(statistic=1.2346386216779992, pvalue=0.2208192912721555)

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
female=dataset[dataset['gender']=='F']['hsc_p']
female1=dataset[dataset['gender']=='F']['degree_p']
ttest_rel(female,female1)
# Out:
# Ttest_relResult(statistic=-1.1005251812027743, pvalue=0.2746230761339702)

# %%
#assignment
from scipy.stats import ttest_rel
dataset=dataset.dropna()
commerce=dataset[dataset['hsc_s']=='COMMERCE']['etest_p']
commerce1=dataset[dataset['hsc_s']=='COMMERCE']['mba_p']
ttest_rel(commerce,commerce1)
# Out:
# Ttest_relResult(statistic=nan, pvalue=nan)

# %%
#HYPOTHESIS TESTING

# %%
#Statement: Test whether ssc_p of male and hsc_p of male is same?

# %%
#Null hypothesis=There is no similarity between 10th pass mark of male and 12th pass mark of male

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
male=dataset[dataset['gender']=='M']['ssc_p']
male1=dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male,male1)
# Out:
# Ttest_relResult(statistic=0.6852881050898078, pvalue=0.49431164600731503)

# %%
#Reject null hypothesis p<0.05
#accept null hypothesis and reject alternate hypothesis

# %%
#ANOVA ANALYSIS
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.6719700864663097, pvalue=0.5110602818995302)

# %%
#two_way analysis
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Example: Two categorical variables 'hsc_s' (HSC stream) and 'specialization', and one numerical variable 'salary'
dataset = dataset.dropna()  # Remove NaN values

# Display column types to ensure correctness
print(dataset.dtypes)
# Out:
# ssc_p             float64
# hsc_p             float64
# degree_p          float64
# etest_p           float64
# mba_p             float64
# salary            float64
# gender             object
# ssc_b              object
# hsc_b              object
# hsc_s              object
# degree_t           object
# workex             object
# specialisation     object
# status             object
# dtype: object

# %%
# Perform Two-Way ANOVA
model = ols('salary ~ C(hsc_s) + C(specialisation) + C(hsc_s):C(specialisation)', data=dataset).fit()
anova_results = sm.stats.anova_lm(model, typ=2)

# Display ANOVA table
print(anova_results)
# Out:
#                                   sum_sq     df         F    PR(>F)
# C(hsc_s)                    1.022337e+10    2.0  0.855497  0.426555
# C(specialisation)           2.135093e+10    1.0  3.573314  0.060099
# C(hsc_s):C(specialisation)  7.222391e+09    2.0  0.604374  0.547369
# Residual                    1.248797e+12  209.0       NaN       NaN
